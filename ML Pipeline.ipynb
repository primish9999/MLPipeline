# %%
import pandas as pd
import os
import biom
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
# Reading Metadata
mddat=pd.read_csv('/Users/priyanka99/Downloads/Metadata.tsv',sep='\t')
mddat
# Out:
#        sample_name sample_type     sex  age_years age_cat  height_cm  \
# 0     10317.000072       Stool    male       73.0     70+      175.0
# 1     10317.000108       Stool    male       52.0     50s      149.0
# 2     10317.000088       Stool  female       39.0     30s      170.0
# 3     10317.000031    Forehead  female       31.0     30s      169.0
# 4     10317.000071       Stool    male       56.0     50s      186.0
# ...            ...         ...     ...        ...     ...        ...
# 3398  10317.000024       Stool    male       58.0     50s      172.0
# 3399  10317.000068       Stool    male       41.0     40s      172.0
# 3400  10317.000099       Stool    male       32.0     30s      178.0
# 3401  10317.000099       Stool  female       33.0     30s      165.0
# 3402  10317.000052       Stool  female       49.0     40s      177.0
#
#       weight_kg    bmi      bmi_cat         country  ...  \
# 0          81.0  26.58   Overweight             USA  ...
# 1          75.0  33.73        Obese  United Kingdom  ...
# 2          77.0  26.63   Overweight             USA  ...
# 3          51.0  17.86  Underweight  Czech Republic  ...
# 4          84.0  24.28       Normal  United Kingdom  ...
# ...         ...    ...          ...             ...  ...
# 3398       74.0  25.09   Overweight             USA  ...
# 3399       79.0  26.61   Overweight             USA  ...
# 3400       63.0  19.88       Normal           Italy  ...
# 3401       56.0  20.57       Normal  United Kingdom  ...
# 3402       67.0  21.39       Normal       Hong Kong  ...
#
#      SeafoodAndPlantProteins_vioscreen_scores Sodium_vioscreen_scores  \
# 0                                    5.000000                2.911640
# 1                                    5.000000                0.000000
# 2                                    5.000000                0.000000
# 3                                    5.000000                0.000000
# 4                                    1.408744                6.419753
# ...                                       ...                     ...
# 3398                                 5.000000                8.625110
# 3399                                 3.661490                3.960061
# 3400                                 1.495665                2.511099
# 3401                                 5.000000                0.740931
# 3402                                 5.000000                6.789578
#
#      TotalFruit_vioscreen_scores TotalProteins_vioscreen_scores  \
# 0                       5.000000                       5.000000
# 1                       1.490069                       5.000000
# 2                       5.000000                       5.000000
# 3                       2.892759                       5.000000
# 4                       5.000000                       3.704020
# ...                          ...                            ...
# 3398                    2.724800                       5.000000
# 3399                    1.377075                       5.000000
# 3400                    5.000000                       3.026161
# 3401                    5.000000                       3.698671
# 3402                    4.180821                       4.571361
#
#      TotalScore_vioscreen_scores TotalVegetables_vioscreen_scores  \
# 0                      76.420115                         5.000000
# 1                      51.007096                         5.000000
# 2                      70.765759                         5.000000
# 3                      79.097956                         5.000000
# 4                      81.697533                         5.000000
# ...                          ...                              ...
# 3398                   76.850005                         3.326484
# 3399                   58.024025                         3.257157
# 3400                   49.468750                         4.760446
# 3401                   73.653572                         5.000000
# 3402                   80.306380                         5.000000
#
#      WholeFruit_vioscreen_scores WholeGrains_vioscreen_scores delta_time_min  \
# 0                       5.000000                     0.734562      37.316500
# 1                       2.965681                     1.592671      19.988950
# 2                       5.000000                     0.000000      11.724950
# 3                       5.000000                     7.461178      32.928400
# 4                       5.000000                    10.000000      39.968783
# ...                          ...                          ...            ...
# 3398                    4.898860                     1.020301      42.372550
# 3399                    2.468266                     2.754148     234.151000
# 3400                    5.000000                     0.302147      21.988000
# 3401                    5.000000                     5.807919      21.434400
# 3402                    5.000000                     1.021307      33.028167
#
#      Johnson_Cell_kcal_prot_fat
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ...                         ...
# 3398                          1
# 3399                          1
# 3400                          1
# 3401                          1
# 3402                          1
#
# [3403 rows x 775 columns]

# %%
#Data Preprocessing
mddat.isna().sum() # Checking for null values
#replace missing values with ?
#Scaling Data
# Out:
# sample_name                           0
# sample_type                           0
# sex                                  23
# age_years                            70
# age_cat                             125
#                                    ...
# TotalVegetables_vioscreen_scores      0
# WholeFruit_vioscreen_scores           0
# WholeGrains_vioscreen_scores          0
# delta_time_min                        0
# Johnson_Cell_kcal_prot_fat            0
# Length: 775, dtype: int64

# %%
#Fitting
